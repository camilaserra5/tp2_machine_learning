# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random as rd
from datetime import datetime
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestClassifier

# %matplotlib inline

# %%
plt.rc('figure',dpi=100);

# %%
training_labels = pd.read_csv("set_entrenamiento.csv", low_memory=False)[['person','label']].head(1960)
training_labels['label'].value_counts()
# Out:
# 1    980
# 0    980
# Name: label, dtype: int64

# %%
def elegir_columnas_random(columnas,n):
    rd.seed(n)
    lista_columnas = columnas.copy()
    cantidad = rd.randint(4, len(lista_columnas))
    columnas_prohibidas = ['person','label','checkout']
    for x in range(cantidad):
        c = rd.choice(lista_columnas)
        if c in columnas_prohibidas:
            continue
        lista_columnas.remove(c)
    return lista_columnas

# %%
def grid_search():
    n_estimators = [20,30,40,50,60,70]
    min_samples_split = [10,20,30,40,50]
    n_jobs = [-5,-1]
    maximos = []
    max_score = 0
    for n_est in n_estimators:
        for min_sam in min_samples_split:
            for n_j in n_jobs:
                c=RandomForestClassifier(n_estimators=n_est,min_samples_split=min_sam,n_jobs=n_j,random_state=0,class_weight="balanced",criterion = 'entropy')
                dt=c.fit(x_train,y_train)
                score=c.score(x_test,y_test)*100
                if max_score < score:
                    maximos = [n_est,min_sam,n_j]
                    max_score = score
                #print("n_estimators : "+ str(n_est)+"; min_samples_split: "+str(min_sam)+"; n_job: "+str(n_j)+"; SCORE: "+ str(score))
    #print("El mejor score fue: "+str(max_score))
    return maximos

# %%
def actualizar_score(score,arbol_score,mejor_arbol_score,cols):
    if score > arbol_score:
        arbol_score = score
    if score > mejor_arbol_score:
        columnas_arbol_mejor_score = cols.copy()
        mejor_arbol_score = score
        sem = x
    return score,arbol_score,mejor_arbol_score,cols

# %%
pd.read_csv("data_set.csv", low_memory = False).columns
# Out:
# Index(['person', 'Email', 'Organic', 'Paid', 'Referral', 'Social', 'Unknown',
#        'ad campaign hit', 'brand listing', 'checkout', 'conversion',
#        'generic listing', 'lead', 'search engine hit', 'searched products',
#        'staticpage', 'viewed product', 'visited site', 'promedio dias',
#        'promedio hora', 'retornos', 'longitud busqueda', 'coincide',
#        'sessions', 'total_time', 'mean_time_by_session', 'max_session_time',
#        'mean_events_by_session', 'max_events_by_session',
#        'days_since_last_session', 'promedio de TFIdf',
#        'different_products_views', 'total_views', 'same_product_max_views'],
#       dtype='object')

# %%
columnas = ['person', 'Email', 'Organic', 'Paid', 'Referral', 'Social', 'Unknown',
       'ad campaign hit', 'brand listing', 'checkout', 'conversion',
       'generic listing', 'lead', 'search engine hit', 'searched products',
       'staticpage', 'viewed product', 'visited site', 'promedio dias',
       'promedio hora', 'retornos', 'longitud busqueda', 'coincide',
       'sessions', 'total_time', 'mean_time_by_session', 'max_session_time',
       'mean_events_by_session', 'max_events_by_session',
       'days_since_last_session', 'promedio de TFIdf',
       'different_products_views', 'total_views', 'same_product_max_views'] #Deben ser columnas del csv que se pasa con los features

# %%
RANDOM_SEED = 123
predicciones = pd.read_csv("trocafone_kaggle_test.csv", low_memory=False)
mejor_arbol_score = 0
columnas_arbol_mejor_score = []
sem = 0
arbol_score = 0
for x in range(200):
    print("Arbol : "+str(x))
    
    #Preparo los dataframe
    training_labels = pd.read_csv("set_entrenamiento.csv", low_memory=False).head(1960)#la idea es pasar un set que sean mitad 0 y mitad 1 sus labels
    labels_predict = pd.read_csv("trocafone_kaggle_test.csv", low_memory=False)
    data = pd.read_csv("data_set.csv", low_memory = False)
    training_labels = training_labels[['person','label']]
    cols = elegir_columnas_random(columnas,x)
    data = data[cols]
    features = pd.merge(training_labels, data, on='person', how='inner')
    features = features.fillna(0)
    
    #Acomodo los sets de test y entrenamiento
    train, test = train_test_split(features,test_size=0.10,random_state=RANDOM_SEED)
    features=list(features.columns)
    features.remove('person')
    features.remove('label')
    x_train=train[features]
    y_train=train['label']
    x_test=test[features]
    y_test=test['label']
    
    #Entreno arbol con los mejores hiperparametros encontrados
    mejores_hiperparmetros = grid_search()
    n_est= mejores_hiperparmetros[0]
    min_sam = mejores_hiperparmetros[1]
    n_j= mejores_hiperparmetros[2]
    c=RandomForestClassifier(n_estimators=n_est,min_samples_split=min_sam,n_jobs=n_j,random_state=0,class_weight="balanced",criterion = 'entropy')
    dt=c.fit(x_train,y_train)
    
    #Veo los resultados
    score=c.score(x_test,y_test)*100
    score,arbol_score,mejor_arbol_score,cols = actualizar_score(score,0,mejor_arbol_score,cols)
    
    #Printeo resultados
    print("Mejor score hasta ahora: "+str(mejor_arbol_score))
    print("Score del arbol: "+str(x)+" es "+str(arbol_score))
    print("Las columnas fueron :" +str(cols))
    print('#--------------------------------------------------------')
    
    #Opcional por si se quiere usar un promedio de todos los resultados para predecir
    prediccion=pd.merge(labels_predict,data,on='person',how='inner')
    prediccion = prediccion.fillna(0)
    x_final=prediccion[features]
    y_final=c.predict(x_final)
    nombre_columna = 'label' +str(x)
    prediccion[nombre_columna]=y_final
    prediccion = prediccion[['person', nombre_columna]]
    predicciones = pd.merge(prediccion,predicciones,on='person',how = 'inner')
    
#Printeo mejor arbol individual    
print('#--------------------------------------------------------')
print("Mejores columnas: "+str(columnas_arbol_mejor_score))
print("Mejor score: "+str(mejor_arbol_score))
print('#--------------------------------------------------------')
# Out:
# Arbol : 0
# Mejor score hasta ahora: 72.95918367346938
# Score del arbol: 0 es 72.95918367346938
# Las columnas fueron :['person', 'checkout', 'promedio dias', 'coincide']
# #--------------------------------------------------------
# Arbol : 1
# Mejor score hasta ahora: 78.57142857142857
# Score del arbol: 1 es 78.57142857142857
# Las columnas fueron :['person', 'Email', 'Organic', 'Paid', 'Social', 'Unknown', 'ad campaign hit', 'checkout', 'conversion', 'generic listing', 'lead', 'search engine hit', 'searched products', 'staticpage', 'promedio hora', 'longitud busqueda', 'coincide', 'sessions', 'total_time', 'mean_time_by_session', 'mean_events_by_session', 'days_since_last_session', 'promedio de TFIdf', 'different_products_views', 'total_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 2
# Mejor score hasta ahora: 78.57142857142857
# Score del arbol: 2 es 73.9795918367347
# Las columnas fueron :['person', 'Organic', 'checkout']
# #--------------------------------------------------------
# Arbol : 3
# Mejor score hasta ahora: 80.10204081632652
# Score del arbol: 3 es 80.10204081632652
# Las columnas fueron :['person', 'Email', 'Paid', 'Referral', 'Social', 'Unknown', 'ad campaign hit', 'checkout', 'generic listing', 'lead', 'search engine hit', 'searched products', 'staticpage', 'viewed product', 'promedio dias', 'retornos', 'coincide', 'mean_time_by_session', 'max_session_time', 'mean_events_by_session', 'max_events_by_session', 'days_since_last_session', 'promedio de TFIdf', 'different_products_views']
# #--------------------------------------------------------
# Arbol : 4
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 4 es 80.61224489795919
# Las columnas fueron :['person', 'Email', 'Social', 'ad campaign hit', 'brand listing', 'checkout', 'conversion', 'generic listing', 'lead', 'searched products', 'staticpage', 'promedio dias', 'retornos', 'longitud busqueda', 'coincide', 'sessions', 'mean_time_by_session', 'max_session_time', 'max_events_by_session', 'days_since_last_session', 'promedio de TFIdf', 'different_products_views', 'total_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 5
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 5 es 76.53061224489795
# Las columnas fueron :['person', 'Paid', 'checkout', 'generic listing', 'promedio hora', 'retornos', 'coincide', 'max_session_time', 'mean_events_by_session', 'promedio de TFIdf', 'different_products_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 6
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 6 es 77.55102040816327
# Las columnas fueron :['person', 'Paid', 'ad campaign hit', 'checkout', 'lead', 'staticpage', 'retornos', 'sessions']
# #--------------------------------------------------------
# Arbol : 7
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 7 es 77.55102040816327
# Las columnas fueron :['person', 'Unknown', 'brand listing', 'checkout', 'generic listing', 'lead', 'search engine hit', 'staticpage', 'viewed product', 'visited site', 'promedio dias', 'retornos', 'longitud busqueda', 'total_time', 'max_session_time', 'mean_events_by_session', 'max_events_by_session', 'promedio de TFIdf', 'different_products_views', 'total_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 8
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 8 es 79.08163265306123
# Las columnas fueron :['person', 'Organic', 'Referral', 'Social', 'checkout', 'conversion', 'search engine hit', 'searched products', 'staticpage', 'viewed product', 'visited site', 'promedio dias', 'promedio hora', 'retornos', 'longitud busqueda', 'total_time', 'mean_events_by_session', 'max_events_by_session', 'days_since_last_session', 'promedio de TFIdf', 'different_products_views', 'total_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 9
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 9 es 79.59183673469387
# Las columnas fueron :['person', 'Paid', 'Referral', 'Unknown', 'ad campaign hit', 'checkout', 'conversion', 'generic listing', 'search engine hit', 'staticpage', 'viewed product', 'promedio hora', 'coincide', 'total_time', 'max_session_time', 'days_since_last_session', 'promedio de TFIdf', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 10
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 10 es 76.53061224489795
# Las columnas fueron :['person', 'Social', 'brand listing', 'checkout', 'generic listing', 'lead', 'visited site', 'retornos', 'longitud busqueda', 'mean_time_by_session', 'mean_events_by_session', 'days_since_last_session', 'promedio de TFIdf']
# #--------------------------------------------------------
# Arbol : 11
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 11 es 77.55102040816327
# Las columnas fueron :['person', 'Referral', 'brand listing', 'checkout', 'conversion', 'generic listing', 'searched products', 'staticpage', 'viewed product', 'promedio hora', 'longitud busqueda', 'coincide', 'max_session_time', 'promedio de TFIdf', 'different_products_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 12
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 12 es 78.57142857142857
# Las columnas fueron :['person', 'Email', 'Organic', 'Paid', 'Social', 'Unknown', 'checkout', 'conversion', 'lead', 'search engine hit', 'searched products', 'staticpage', 'promedio hora', 'retornos', 'coincide', 'max_events_by_session', 'days_since_last_session', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 13
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 13 es 79.59183673469387
# Las columnas fueron :['person', 'Email', 'Paid', 'ad campaign hit', 'checkout', 'conversion', 'lead', 'search engine hit', 'searched products', 'viewed product', 'visited site', 'promedio hora', 'retornos', 'longitud busqueda', 'coincide', 'sessions', 'mean_time_by_session', 'mean_events_by_session', 'max_events_by_session', 'days_since_last_session', 'different_products_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 14
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 14 es 79.08163265306123
# Las columnas fueron :['person', 'Email', 'Organic', 'Paid', 'Referral', 'Social', 'Unknown', 'ad campaign hit', 'checkout', 'generic listing', 'lead', 'search engine hit', 'searched products', 'viewed product', 'visited site', 'promedio hora', 'retornos', 'longitud busqueda', 'coincide', 'sessions', 'total_time', 'max_session_time', 'mean_events_by_session', 'days_since_last_session', 'promedio de TFIdf', 'different_products_views', 'total_views']
# #--------------------------------------------------------
# Arbol : 15
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 15 es 76.53061224489795
# Las columnas fueron :['person', 'Paid', 'Referral', 'checkout', 'coincide', 'sessions']
# #--------------------------------------------------------
# Arbol : 16
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 16 es 79.59183673469387
# Las columnas fueron :['person', 'Email', 'Organic', 'Paid', 'Referral', 'Social', 'Unknown', 'checkout', 'conversion', 'generic listing', 'lead', 'searched products', 'visited site', 'promedio hora', 'retornos', 'longitud busqueda', 'coincide', 'sessions', 'total_time', 'mean_time_by_session', 'days_since_last_session', 'total_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 17
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 17 es 77.55102040816327
# Las columnas fueron :['person', 'Email', 'Organic', 'Referral', 'Unknown', 'ad campaign hit', 'brand listing', 'checkout', 'generic listing', 'lead', 'staticpage', 'visited site', 'longitud busqueda', 'coincide', 'promedio de TFIdf', 'different_products_views', 'total_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 18
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 18 es 77.55102040816327
# Las columnas fueron :['person', 'Email', 'Organic', 'Paid', 'Referral', 'checkout', 'conversion', 'generic listing', 'lead', 'search engine hit', 'searched products', 'staticpage', 'viewed product', 'visited site', 'retornos', 'longitud busqueda', 'sessions', 'total_time', 'max_session_time', 'mean_events_by_session', 'max_events_by_session', 'promedio de TFIdf', 'different_products_views', 'total_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 19
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 19 es 77.04081632653062
# Las columnas fueron :['person', 'Paid', 'checkout', 'viewed product', 'promedio hora', 'coincide', 'promedio de TFIdf', 'different_products_views', 'total_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 20
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 20 es 76.0204081632653
# Las columnas fueron :['person', 'ad campaign hit', 'checkout', 'searched products', 'longitud busqueda', 'days_since_last_session']
# #--------------------------------------------------------
# Arbol : 21
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 21 es 80.10204081632652
# Las columnas fueron :['person', 'Email', 'Organic', 'Paid', 'Referral', 'Social', 'ad campaign hit', 'brand listing', 'checkout', 'conversion', 'generic listing', 'lead', 'search engine hit', 'searched products', 'viewed product', 'promedio hora', 'retornos', 'longitud busqueda', 'coincide', 'sessions', 'total_time', 'mean_time_by_session', 'max_events_by_session', 'days_since_last_session', 'total_views']
# #--------------------------------------------------------
# Arbol : 22
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 22 es 76.0204081632653
# Las columnas fueron :['person', 'checkout', 'total_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 23
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 23 es 77.55102040816327
# Las columnas fueron :['person', 'Organic', 'ad campaign hit', 'checkout', 'retornos', 'max_session_time', 'days_since_last_session']
# #--------------------------------------------------------
# Arbol : 24
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 24 es 77.55102040816327
# Las columnas fueron :['person', 'Email', 'Paid', 'checkout', 'search engine hit', 'staticpage', 'promedio dias', 'promedio hora', 'retornos', 'max_session_time']
# #--------------------------------------------------------
# Arbol : 25
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 25 es 79.59183673469387
# Las columnas fueron :['person', 'Paid', 'Referral', 'ad campaign hit', 'brand listing', 'checkout', 'conversion', 'lead', 'searched products', 'staticpage', 'viewed product', 'promedio dias', 'promedio hora', 'longitud busqueda', 'coincide', 'total_time', 'mean_time_by_session', 'max_events_by_session', 'different_products_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 26
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 26 es 77.04081632653062
# Las columnas fueron :['person', 'Paid', 'checkout', 'staticpage', 'viewed product', 'visited site', 'max_events_by_session', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 27
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 27 es 76.0204081632653
# Las columnas fueron :['person', 'Email', 'ad campaign hit', 'checkout', 'conversion', 'viewed product', 'total_time', 'max_session_time', 'mean_events_by_session', 'max_events_by_session', 'different_products_views']
# #--------------------------------------------------------
# Arbol : 28
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 28 es 79.08163265306123
# Las columnas fueron :['person', 'Email', 'Organic', 'Paid', 'Social', 'Unknown', 'ad campaign hit', 'checkout', 'conversion', 'generic listing', 'search engine hit', 'searched products', 'staticpage', 'visited site', 'promedio hora', 'retornos', 'longitud busqueda', 'coincide', 'sessions', 'mean_time_by_session', 'max_session_time', 'mean_events_by_session', 'max_events_by_session', 'days_since_last_session', 'different_products_views', 'total_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 29
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 29 es 78.06122448979592
# Las columnas fueron :['person', 'Paid', 'ad campaign hit', 'brand listing', 'checkout', 'conversion', 'searched products', 'retornos', 'mean_time_by_session', 'max_session_time', 'mean_events_by_session', 'promedio de TFIdf', 'total_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 30
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 30 es 79.08163265306123
# Las columnas fueron :['person', 'Paid', 'ad campaign hit', 'brand listing', 'checkout', 'lead', 'search engine hit', 'visited site', 'promedio hora', 'retornos', 'longitud busqueda', 'mean_events_by_session', 'max_events_by_session', 'days_since_last_session', 'different_products_views', 'total_views']
# #--------------------------------------------------------
# Arbol : 31
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 31 es 78.57142857142857
# Las columnas fueron :['person', 'Email', 'Organic', 'Paid', 'Social', 'Unknown', 'brand listing', 'checkout', 'conversion', 'generic listing', 'lead', 'search engine hit', 'searched products', 'staticpage', 'viewed product', 'visited site', 'promedio dias', 'promedio hora', 'retornos', 'longitud busqueda', 'coincide', 'sessions', 'total_time', 'mean_time_by_session', 'mean_events_by_session', 'max_events_by_session', 'days_since_last_session', 'different_products_views', 'total_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 32
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 32 es 80.61224489795919
# Las columnas fueron :['person', 'Email', 'Organic', 'Paid', 'Referral', 'Social', 'Unknown', 'ad campaign hit', 'brand listing', 'checkout', 'conversion', 'generic listing', 'lead', 'searched products', 'staticpage', 'promedio dias', 'promedio hora', 'longitud busqueda', 'coincide', 'sessions', 'total_time', 'mean_time_by_session', 'max_session_time', 'mean_events_by_session', 'max_events_by_session', 'days_since_last_session', 'promedio de TFIdf', 'different_products_views', 'total_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 33
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 33 es 77.04081632653062
# Las columnas fueron :['person', 'Email', 'Paid', 'Referral', 'ad campaign hit', 'checkout', 'search engine hit', 'viewed product', 'days_since_last_session', 'promedio de TFIdf', 'different_products_views', 'total_views']
# #--------------------------------------------------------
# Arbol : 34
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 34 es 79.59183673469387
# Las columnas fueron :['person', 'Organic', 'Referral', 'brand listing', 'checkout', 'conversion', 'searched products', 'visited site', 'retornos', 'longitud busqueda', 'sessions', 'mean_time_by_session', 'mean_events_by_session', 'days_since_last_session', 'promedio de TFIdf', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 35
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 35 es 78.57142857142857
# Las columnas fueron :['person', 'Organic', 'Paid', 'ad campaign hit', 'checkout', 'lead', 'searched products', 'staticpage', 'visited site', 'promedio hora', 'coincide', 'max_session_time', 'mean_events_by_session', 'max_events_by_session', 'days_since_last_session']
# #--------------------------------------------------------
# Arbol : 36
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 36 es 79.08163265306123
# Las columnas fueron :['person', 'Organic', 'Social', 'Unknown', 'ad campaign hit', 'checkout', 'conversion', 'lead', 'searched products', 'staticpage', 'viewed product', 'visited site', 'promedio dias', 'coincide', 'sessions', 'total_time', 'max_session_time', 'mean_events_by_session', 'max_events_by_session', 'promedio de TFIdf', 'total_views']
# #--------------------------------------------------------
# Arbol : 37
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 37 es 80.10204081632652
# Las columnas fueron :['person', 'brand listing', 'checkout', 'conversion', 'staticpage', 'longitud busqueda', 'days_since_last_session', 'promedio de TFIdf', 'total_views']
# #--------------------------------------------------------
# Arbol : 38
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 38 es 80.10204081632652
# Las columnas fueron :['person', 'Paid', 'Referral', 'ad campaign hit', 'checkout', 'generic listing', 'staticpage', 'coincide', 'sessions', 'total_views']
# #--------------------------------------------------------
# Arbol : 39
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 39 es 79.59183673469387
# Las columnas fueron :['person', 'Organic', 'Paid', 'Referral', 'Social', 'Unknown', 'brand listing', 'checkout', 'conversion', 'generic listing', 'lead', 'search engine hit', 'staticpage', 'visited site', 'promedio dias', 'promedio hora', 'retornos', 'longitud busqueda', 'sessions', 'total_time', 'mean_events_by_session', 'days_since_last_session', 'promedio de TFIdf', 'different_products_views', 'total_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 40
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 40 es 78.57142857142857
# Las columnas fueron :['person', 'Paid', 'Referral', 'brand listing', 'checkout', 'generic listing', 'searched products', 'visited site', 'promedio dias', 'promedio hora', 'retornos', 'coincide', 'mean_time_by_session', 'max_events_by_session', 'days_since_last_session', 'promedio de TFIdf', 'different_products_views']
# #--------------------------------------------------------
# Arbol : 41
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 41 es 78.57142857142857
# Las columnas fueron :['person', 'Email', 'Organic', 'Paid', 'Referral', 'Social', 'Unknown', 'checkout', 'generic listing', 'lead', 'staticpage', 'visited site', 'promedio dias', 'promedio hora', 'sessions', 'total_time', 'mean_time_by_session', 'max_events_by_session', 'days_since_last_session', 'promedio de TFIdf', 'total_views']
# #--------------------------------------------------------
# Arbol : 42
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 42 es 77.04081632653062
# Las columnas fueron :['person', 'Unknown', 'checkout', 'generic listing', 'lead', 'viewed product', 'visited site', 'retornos', 'longitud busqueda', 'sessions', 'total_time', 'max_events_by_session', 'different_products_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 43
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 43 es 78.57142857142857
# Las columnas fueron :['person', 'Email', 'Organic', 'Paid', 'Referral', 'Social', 'Unknown', 'ad campaign hit', 'brand listing', 'checkout', 'conversion', 'generic listing', 'lead', 'search engine hit', 'searched products', 'staticpage', 'viewed product', 'visited site', 'promedio hora', 'retornos', 'longitud busqueda', 'sessions', 'mean_time_by_session', 'max_session_time', 'mean_events_by_session', 'max_events_by_session', 'days_since_last_session', 'different_products_views', 'total_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 44
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 44 es 79.59183673469387
# Las columnas fueron :['person', 'Email', 'Organic', 'Social', 'Unknown', 'checkout', 'conversion', 'search engine hit', 'staticpage', 'visited site', 'promedio dias', 'promedio hora', 'retornos', 'longitud busqueda', 'coincide', 'mean_time_by_session', 'max_session_time', 'mean_events_by_session', 'max_events_by_session', 'days_since_last_session', 'promedio de TFIdf']
# #--------------------------------------------------------
# Arbol : 45
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 45 es 80.10204081632652
# Las columnas fueron :['person', 'Email', 'Referral', 'Unknown', 'ad campaign hit', 'brand listing', 'checkout', 'generic listing', 'search engine hit', 'staticpage', 'visited site', 'promedio dias', 'promedio hora', 'longitud busqueda', 'coincide', 'sessions', 'total_time', 'mean_time_by_session', 'mean_events_by_session', 'max_events_by_session', 'days_since_last_session', 'promedio de TFIdf', 'different_products_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 46
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 46 es 77.55102040816327
# Las columnas fueron :['person', 'brand listing', 'checkout', 'generic listing', 'lead', 'viewed product']
# #--------------------------------------------------------
# Arbol : 47
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 47 es 79.08163265306123
# Las columnas fueron :['person', 'Organic', 'Paid', 'Unknown', 'ad campaign hit', 'brand listing', 'checkout', 'conversion', 'lead', 'search engine hit', 'viewed product', 'visited site', 'longitud busqueda', 'coincide', 'sessions', 'total_time', 'max_session_time', 'mean_events_by_session', 'days_since_last_session', 'promedio de TFIdf', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 48
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 48 es 78.06122448979592
# Las columnas fueron :['person', 'Email', 'Organic', 'checkout', 'conversion', 'search engine hit', 'searched products', 'viewed product', 'promedio dias', 'promedio hora', 'coincide', 'sessions', 'mean_time_by_session', 'max_session_time']
# #--------------------------------------------------------
# Arbol : 49
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 49 es 80.61224489795919
# Las columnas fueron :['person', 'Email', 'Organic', 'Paid', 'Referral', 'Social', 'Unknown', 'brand listing', 'checkout', 'conversion', 'lead', 'search engine hit', 'searched products', 'staticpage', 'viewed product', 'visited site', 'promedio dias', 'retornos', 'longitud busqueda', 'sessions', 'total_time', 'mean_time_by_session', 'max_session_time', 'days_since_last_session', 'promedio de TFIdf', 'different_products_views', 'total_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 50
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 50 es 78.06122448979592
# Las columnas fueron :['person', 'Email', 'Referral', 'ad campaign hit', 'checkout', 'generic listing', 'search engine hit', 'searched products', 'promedio dias', 'promedio hora', 'max_session_time', 'max_events_by_session', 'promedio de TFIdf', 'different_products_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 51
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 51 es 79.08163265306123
# Las columnas fueron :['person', 'Email', 'Organic', 'Paid', 'Referral', 'Social', 'Unknown', 'brand listing', 'checkout', 'generic listing', 'lead', 'search engine hit', 'staticpage', 'visited site', 'promedio hora', 'longitud busqueda', 'sessions', 'total_time', 'mean_time_by_session', 'max_session_time', 'mean_events_by_session', 'days_since_last_session', 'different_products_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 52
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 52 es 79.08163265306123
# Las columnas fueron :['person', 'Organic', 'Referral', 'Social', 'ad campaign hit', 'checkout', 'conversion', 'generic listing', 'search engine hit', 'searched products', 'viewed product', 'promedio dias', 'retornos', 'longitud busqueda', 'coincide', 'sessions', 'total_time', 'mean_time_by_session', 'max_session_time', 'mean_events_by_session', 'days_since_last_session', 'promedio de TFIdf', 'total_views']
# #--------------------------------------------------------
# Arbol : 53
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 53 es 79.08163265306123
# Las columnas fueron :['person', 'Referral', 'ad campaign hit', 'checkout', 'conversion', 'searched products', 'retornos', 'longitud busqueda', 'total_time', 'mean_time_by_session', 'max_session_time', 'max_events_by_session', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 54
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 54 es 75.51020408163265
# Las columnas fueron :['person', 'Social', 'checkout', 'max_events_by_session', 'promedio de TFIdf']
# #--------------------------------------------------------
# Arbol : 55
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 55 es 79.08163265306123
# Las columnas fueron :['person', 'Email', 'Organic', 'Paid', 'Referral', 'ad campaign hit', 'brand listing', 'checkout', 'conversion', 'generic listing', 'search engine hit', 'searched products', 'staticpage', 'viewed product', 'visited site', 'promedio dias', 'promedio hora', 'longitud busqueda', 'coincide', 'sessions', 'total_time', 'mean_time_by_session', 'mean_events_by_session', 'max_events_by_session', 'days_since_last_session', 'promedio de TFIdf', 'different_products_views', 'total_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 56
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 56 es 77.04081632653062
# Las columnas fueron :['person', 'checkout', 'conversion', 'retornos', 'coincide', 'mean_time_by_session']
# #--------------------------------------------------------
# Arbol : 57
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 57 es 79.08163265306123
# Las columnas fueron :['person', 'Organic', 'Paid', 'Referral', 'Social', 'Unknown', 'ad campaign hit', 'brand listing', 'checkout', 'conversion', 'lead', 'search engine hit', 'searched products', 'viewed product', 'visited site', 'promedio hora', 'retornos', 'longitud busqueda', 'coincide', 'total_time', 'mean_time_by_session', 'max_session_time', 'mean_events_by_session', 'max_events_by_session', 'days_since_last_session', 'promedio de TFIdf', 'different_products_views', 'total_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 58
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 58 es 79.08163265306123
# Las columnas fueron :['person', 'Organic', 'Social', 'Unknown', 'brand listing', 'checkout', 'staticpage', 'longitud busqueda', 'coincide', 'mean_time_by_session', 'max_session_time', 'mean_events_by_session', 'max_events_by_session', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 59
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 59 es 78.57142857142857
# Las columnas fueron :['person', 'Organic', 'Paid', 'Referral', 'ad campaign hit', 'brand listing', 'checkout', 'conversion', 'generic listing', 'search engine hit', 'searched products', 'staticpage', 'viewed product', 'visited site', 'promedio dias', 'promedio hora', 'retornos', 'longitud busqueda', 'coincide', 'total_time', 'mean_events_by_session', 'max_events_by_session', 'days_since_last_session', 'total_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 60
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 60 es 80.10204081632652
# Las columnas fueron :['person', 'Organic', 'Referral', 'Social', 'Unknown', 'brand listing', 'checkout', 'generic listing', 'lead', 'search engine hit', 'promedio hora', 'retornos', 'longitud busqueda', 'coincide', 'sessions', 'total_time', 'mean_time_by_session', 'max_session_time', 'mean_events_by_session', 'days_since_last_session', 'different_products_views', 'total_views']
# #--------------------------------------------------------
# Arbol : 61
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 61 es 78.57142857142857
# Las columnas fueron :['person', 'Email', 'Paid', 'Referral', 'Social', 'ad campaign hit', 'brand listing', 'checkout', 'lead', 'visited site', 'longitud busqueda', 'total_time', 'mean_time_by_session', 'mean_events_by_session', 'max_events_by_session', 'promedio de TFIdf', 'total_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 62
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 62 es 73.46938775510205
# Las columnas fueron :['person', 'Social', 'checkout', 'lead', 'promedio hora', 'coincide']
# #--------------------------------------------------------
# Arbol : 63
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 63 es 78.57142857142857
# Las columnas fueron :['person', 'Unknown', 'ad campaign hit', 'brand listing', 'checkout', 'conversion', 'generic listing', 'promedio hora', 'retornos', 'longitud busqueda', 'coincide', 'sessions', 'mean_time_by_session', 'max_session_time', 'mean_events_by_session', 'days_since_last_session', 'total_views']
# #--------------------------------------------------------
# Arbol : 64
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 64 es 79.08163265306123
# Las columnas fueron :['person', 'Organic', 'Referral', 'Unknown', 'checkout', 'conversion', 'search engine hit', 'searched products', 'staticpage', 'viewed product', 'visited site', 'promedio dias', 'retornos', 'coincide', 'sessions', 'max_events_by_session', 'promedio de TFIdf']
# #--------------------------------------------------------
# Arbol : 65
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 65 es 78.57142857142857
# Las columnas fueron :['person', 'Email', 'Paid', 'Referral', 'Social', 'Unknown', 'checkout', 'lead', 'search engine hit', 'coincide', 'sessions', 'mean_time_by_session', 'mean_events_by_session', 'max_events_by_session', 'different_products_views', 'total_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 66
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 66 es 79.59183673469387
# Las columnas fueron :['person', 'Email', 'Organic', 'Paid', 'Referral', 'Social', 'Unknown', 'ad campaign hit', 'brand listing', 'checkout', 'conversion', 'generic listing', 'lead', 'search engine hit', 'viewed product', 'visited site', 'promedio dias', 'retornos', 'longitud busqueda', 'coincide', 'sessions', 'total_time', 'mean_time_by_session', 'max_session_time', 'days_since_last_session', 'promedio de TFIdf', 'different_products_views', 'total_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 67
# Mejor score hasta ahora: 80.61224489795919
# Score del arbol: 67 es 79.08163265306123
# Las columnas fueron :['person', 'Email', 'Organic', 'Paid', 'Referral', 'Social', 'Unknown', 'brand listing', 'checkout', 'conversion', 'generic listing', 'lead', 'search engine hit', 'staticpage', 'viewed product', 'visited site', 'promedio dias', 'promedio hora', 'retornos', 'coincide', 'sessions', 'total_time', 'mean_time_by_session', 'max_session_time', 'max_events_by_session', 'days_since_last_session', 'promedio de TFIdf', 'total_views', 'same_product_max_views']
# #--------------------------------------------------------
# Arbol : 68

# %%
predicciones.to_csv('../modelos/RandomForestResults_ensamble.csv',index=False)
