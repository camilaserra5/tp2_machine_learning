# %%
import pandas as pd
import numpy as np
import datetime
from datetime import datetime, timedelta
import utils
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=RuntimeWarning)

# %%
events = utils.get_events()

# %%
events.head()
# Out:
#             timestamp           event    person  url      sku  \
# 0 2018-05-18 00:11:59  viewed product  4886f805  NaN   9288.0
# 1 2018-05-18 00:11:27  viewed product  ad93850f  NaN    304.0
# 2 2018-05-18 00:11:16  viewed product  0297fc1e  NaN   6888.0
# 3 2018-05-18 00:11:14  viewed product  2d681dd8  NaN  11890.0
# 4 2018-05-18 00:11:09  viewed product  cccea85e  NaN   7517.0
#
#                      model  condition storage           color skus ...  city  \
# 0  Samsung Galaxy J7 Prime  Excelente    32GB         Dourado  NaN ...   NaN
# 1                iPhone 5s  Muito Bom    32GB  Cinza espacial  NaN ...   NaN
# 2                iPhone 6S  Muito Bom    64GB        Prateado  NaN ...   NaN
# 3                 iPhone 7        Bom   128GB        Vermelho  NaN ...   NaN
# 4              LG G4 H818P  Excelente    32GB          Branco  NaN ...   NaN
#
#   region country device_type screen_resolution operating_system_version  \
# ...

# %%
events_url = events.dropna(subset = ['url'])

# %%
events_url
# Out:
#                   timestamp            event    person  \
# 9       2018-05-18 00:43:40  ad campaign hit  45baf068
# 14      2018-05-18 00:40:09  ad campaign hit  45baf068
# 20      2018-05-18 00:36:16  ad campaign hit  29ebb414
# 34      2018-05-18 00:29:15  ad campaign hit  2a724d87
# 38      2018-05-18 00:28:15  ad campaign hit  15ea8012
# 41      2018-05-18 00:27:30  ad campaign hit  4c8a8b93
# 59      2018-05-18 00:22:59  ad campaign hit  6e6770c3
# 68      2018-05-18 00:21:08  ad campaign hit  d6bc64df
# 69      2018-05-18 00:20:55  ad campaign hit  15ea8012
# 78      2018-05-18 00:38:34  ad campaign hit  8ea4c165
# 83      2018-05-18 00:37:25  ad campaign hit  4e03ed9a
# 84      2018-05-18 00:37:16  ad campaign hit  8ea4c165
# 102     2018-05-18 00:51:51  ad campaign hit  8f1679ff
# 113     2018-05-18 00:28:29  ad campaign hit  15ea8012
# 138     2018-05-18 00:55:13  ad campaign hit  f87be219
# 180     2018-05-18 00:15:23  ad campaign hit  dca7e4fa
# ...

# %%
events_url['url_compra'] = events_url['url'].map(lambda x: 1 if 'comprar' in x.split('/') else 0)

# %%
events_ur = pd.DataFrame(events_url.groupby('person')['url_compra'].agg({'suma_url_compra':sum})).reset_index()[['person','suma_url_compra']]

# %%
#marcas = ['asus','motorola','iphone','samsung']
#def repite_marca(marcas):

# %%
events_ur.to_csv('features_url.csv', index=False)
