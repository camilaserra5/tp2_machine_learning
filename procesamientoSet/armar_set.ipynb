# %%
import pandas as pd
import numpy as np
import datetime
from datetime import datetime, timedelta
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=RuntimeWarning)

# %%
eventos1 = pd.read_csv('events_up_to_01062018.csv',low_memory=False)
eventos2 = pd.read_csv('events.csv',low_memory=False)

# %%
eventos1.head()
# Out:
#              timestamp           event    person  url      sku  \
# 0  2018-05-18 00:11:59  viewed product  4886f805  NaN   9288.0
# 1  2018-05-18 00:11:27  viewed product  ad93850f  NaN    304.0
# 2  2018-05-18 00:11:16  viewed product  0297fc1e  NaN   6888.0
# 3  2018-05-18 00:11:14  viewed product  2d681dd8  NaN  11890.0
# 4  2018-05-18 00:11:09  viewed product  cccea85e  NaN   7517.0
#
#                      model  condition storage           color skus  \
# 0  Samsung Galaxy J7 Prime  Excelente    32GB         Dourado  NaN
# 1                iPhone 5s  Muito Bom    32GB  Cinza espacial  NaN
# 2                iPhone 6S  Muito Bom    64GB        Prateado  NaN
# 3                 iPhone 7        Bom   128GB        Vermelho  NaN
# 4              LG G4 H818P  Excelente    32GB          Branco  NaN
#
#         ...       search_engine channel new_vs_returning city region country  \
# 0       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# ...

# %%
eventos2.head()
# Out:
#              timestamp            event    person                        url  \
# 0  2018-05-31 23:38:05  ad campaign hit  0004b0a2  /comprar/iphone/iphone-5s
# 1  2018-05-31 23:38:05     visited site  0004b0a2                        NaN
# 2  2018-05-31 23:38:09   viewed product  0004b0a2                        NaN
# 3  2018-05-31 23:38:40         checkout  0004b0a2                        NaN
# 4  2018-05-29 13:29:25   viewed product  0006a21a                        NaN
#
#        sku              model condition storage           color skus  \
# 0      NaN                NaN       NaN     NaN             NaN  NaN
# 1      NaN                NaN       NaN     NaN             NaN  NaN
# 2   2694.0          iPhone 5s       Bom    32GB  Cinza espacial  NaN
# 3   2694.0          iPhone 5s       Bom    32GB  Cinza espacial  NaN
# 4  15338.0  Samsung Galaxy S8       Bom    64GB         Dourado  NaN
#
#          ...        search_engine channel new_vs_returning        city  \
# ...

# %%
print(eventos1.shape)
print(eventos2.shape)
# Out:
# (2341681, 23)
# (1011288, 23)

# %%
eventos = eventos1.append(eventos2, ignore_index = True)
eventos.shape
# Out:
# (3352969, 23)

# %% [markdown]
# #### Me quedo con las compras y le agrego label

# %%
compras = eventos[eventos['event'] == 'conversion']
compras.shape
# Out:
# (8263, 23)

# %%
compras['label'] = 1
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
compras = compras[['person','label']]
compras.head()
# Out:
#         person  label
# 195   49c19e32      1
# 234   49c19e32      1
# 724   39df97e0      1
# 744   380c0e60      1
# 1198  35ee0cc8      1

# %% [markdown]
# #### Vuevlo a juntar y escribo csv

# %%
eventos = pd.merge(eventos, compras, on = 'person',how = 'left')
eventos['label'] = eventos['label'].map(lambda x: 1 if x==1 else 0)
eventos.head()
# Out:
#              timestamp           event    person  url    sku  \
# 0  2018-05-18 00:11:59  viewed product  4886f805  NaN   9288
# 1  2018-05-18 00:11:27  viewed product  ad93850f  NaN    304
# 2  2018-05-18 00:11:16  viewed product  0297fc1e  NaN   6888
# 3  2018-05-18 00:11:14  viewed product  2d681dd8  NaN  11890
# 4  2018-05-18 00:11:09  viewed product  cccea85e  NaN   7517
#
#                      model  condition storage           color skus  ...   \
# 0  Samsung Galaxy J7 Prime  Excelente    32GB         Dourado  NaN  ...
# 1                iPhone 5s  Muito Bom    32GB  Cinza espacial  NaN  ...
# 2                iPhone 6S  Muito Bom    64GB        Prateado  NaN  ...
# 3                 iPhone 7        Bom   128GB        Vermelho  NaN  ...
# 4              LG G4 H818P  Excelente    32GB          Branco  NaN  ...
#
#   channel new_vs_returning city region country device_type screen_resolution  \
# 0     NaN              NaN  NaN    NaN     NaN         NaN               NaN
# ...

# %%
eventos['label'].value_counts()
# Out:
# 0    2580093
# 1    1950592
# Name: label, dtype: int64

# %%
eventos.to_csv('../modelos/set_entrenamiento.csv',index=False)

# %%
training = eventos[['person','label']]
training = training.drop_duplicates(subset = 'person')
set_reducido_0 = training[training['label'] == 0].sample(n=10000)
set_entrenamiento = training[training['label'] == 1].append(set_reducido_0)
set_entrenamiento.shape
set_entrenamiento.to_csv('../modelos/labels_training_set.csv',index=False)

# %%
set_entrenamiento.shape
# Out:
# (15009, 2)
